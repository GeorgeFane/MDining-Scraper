# %% [markdown]
# <a href="https://colab.research.google.com/github/GeorgeFane/MDining-Scraper/blob/master/MDining_Scraper_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext google.colab.data_table
import pandas as pd 
from datetime import datetime as dt
from pytz import timezone

tz = timezone("America/Detroit")
ptime = lambda string, form: dt.strptime(string, form).time()
now = lambda: dt.now(tz).strftime('%-d %b %Y %-I:%M %p')
 
def isOpen(time):
    start, end = time.split(' ‑ ')
    return ptime(start, '%I:%M %p') < dt.now(tz).time() < ptime(end, '%I:%M %p')

url = 'https://raw.githubusercontent.com/GeorgeFane/MDining-Scraper/master/scraped.txt'
df = pd.read_csv(url, index_col=0)

bools = [isOpen(time) for time in df['Time']]
df.insert(0, 'isOpen', bools)

print('\nUpdated ' + now())
df
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table
#
# Updated 2 Nov 2020 10:54 AM
#     isOpen  ...                                              Foods
# 0    False  ...  ['Oatmeal ', 'Pancakes ', 'Turkey Sausage Patt...
# 1     True  ...  ['Cream of Broccoli Soup ', 'Turkey w/ French ...
# 2    False  ...  ['Cream of Broccoli Soup ', 'MSC Pub Style Fis...
# 3    False  ...  ['Caramelized Onion and Chicken Pizza ', 'Roas...
# 4    False  ...  ['Organic Steel-Cut Oatmeal', 'Grilled Vegetab...
# 5     True  ...  ['Cream of Broccoli Soup ', 'Garden Salad', 'G...
# 6    False  ...  ['Cream of Broccoli Soup ', 'Garden Salad', 'G...
# 7    False  ...  ['Oatmeal ', 'Scrambled Eggs  ', 'Pancakes ', ...
# 8     True  ...  ['Chicken Vegetable Soup ', 'Cream of Broccoli...
# 9    False  ...  ['Chicken Vegetable Soup ', 'Cream of Broccoli...
# 10   False  ...  ['Oatmeal ', 'Fresh Fruit ', 'Hard Cooked Eggs...
# 11    True  ...  ['Cream of Broccoli Soup ', 'Fresh Fruit ', 'G...
# 12   False  ...  ['Cream of Broccoli Soup ', 'Fresh Fruit ', 'G...
# 13   False  ...  ['Oatmeal ', 'Pancakes ', 'Sweet Potato Wedges...
# 14    True  ...  ['Cream of Broccoli Soup ', 'Entree Garden Sal...
# 15   False  ...  ['Cream of Broccoli Soup ', 'Entree Garden Sal...
# 16   False  ...  ['Oatmeal ', 'Sweet Potato Tots ', 'Scrambled ...
# 17    True  ...  ['Cream of Broccoli Soup ', 'Fulgobi Bhaaji', ...
# 18   False  ...  ['Cream of Broccoli Soup ', 'MSC Fried Battere...
# 19   False  ...  ['Scrambled Eggs  ', 'Scrambled Tofu ', 'Black...
# 20    True  ...  ['Chicken Carnitas', 'Vegan Creamy Pinto Beans...
# 21   False  ...  ['Tuscan Grilled Chicken', 'Wild Rice Blend ',...
# 22   False  ...  ['Tuscan Grilled Chicken', 'Wild Rice Blend ',...
# 23    True  ...  ['Halal Turkey Sandwich', 'Grilled Chicken & T...
# 24   False  ...  ['Beef Stroganoff with Spaetzle & Broccoli', '...
# 25    True  ...  ['Halal Turkey Sandwich', 'Grilled Chicken & T...
# 26   False  ...  ['Beef Stroganoff with Spaetzle & Broccoli', '...
# 27    True  ...  ['Halal Turkey Sandwich', 'Grilled Chicken & T...
# 28   False  ...  ['Beef Stroganoff with Spaetzle & Broccoli', '...
#
# [29 rows x 5 columns]
